# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import datetime

# %%
data = pd.read_csv('EIA Data Sets/Data/net_generation.csv')
data.head()
# Out:
#         Date  \
# 0  12/1/2020
# 1  11/1/2020
# 2  10/1/2020
# 3   9/1/2020
# 4   8/1/2020
#
#    Electric power sector net generation from biomass, United States, Monthly (billion kilowatthours)  \
# 0                                           1.862813
# 1                                           1.638054
# 2                                           2.264039
# 3                                           1.954046
# 4                                           2.114324
#
#    Electric power sector net generation from coal, United States, Monthly (billion kilowatthours)  \
# 0                                           70.54828
# 1                                           55.38093
# 2                                           57.85693
# 3                                           63.53742
# 4                                           93.90338
#
#    Net energy for electricity load, United States, Monthly (billion kilowatthours)  \
# 0                                           326.5772
# 1                                           292.8734
# 2                                           306.3560
# 3                                           318.2363
# 4                                           388.0824
#
#    Electric power sector net generation from geothermal, United States, Monthly (billion kilowatthours)  \
# 0                                           1.512993
# 1                                           1.431412
# 2                                           1.337518
# 3                                           1.379625
# 4                                           1.376648
#
#    Electric power sector net generation from pumped storage hydropower, United States, Monthly (billion kilowatthours)  \
# 0                                          -0.496784
# 1                                          -0.336250
# 2                                          -0.442759
# 3                                          -0.620189
# 4                                          -0.752724
#
#    Electric power sector net generation from conventional hydropower, United States, Monthly (billion kilowatthours)  \
# 0                                           23.82805
# 1                                           20.84670
# 2                                           19.63240
# 3                                           18.59246
# 4                                           21.51756
#
#    Electric power sector net generation from natural gas, United States, Monthly (billion kilowatthours)  \
# 0                                           116.4394
# 1                                           111.2597
# 2                                           126.3004
# 3                                           136.5059
# 4                                           162.1831
#
#    Electric power sector net generation from nuclear, United States, Monthly (billion kilowatthours)  \
# 0                                           72.54646
# 1                                           66.10233
# 2                                           61.42273
# 3                                           63.85781
# 4                                           70.26038
#
#    Electric power sector net generation from other nonrenewable fuels, United States, Monthly (billion kilowatthours)  \
# 0                                           0.640074
# 1                                           0.605994
# 2                                           0.613575
# 3                                           0.327863
# 4                                           0.490478
#
#    Electric power sector net generation from other gases, United States, Monthly (billion kilowatthours)  \
# 0                                           0.428227
# 1                                           0.317438
# 2                                           0.156562
# 3                                           0.345714
# 4                                           0.413946
#
#    Electric power sector net generation from petroleum, United States, Monthly (billion kilowatthours)  \
# 0                                           1.589645
# 1                                           1.562592
# 2                                           1.326140
# 3                                           1.804214
# 4                                           1.889336
#
#    Electric power sector net generation from renewable energy (all types), United States, Monthly (billion kilowatthours)  \
# 0                                           64.88192
# 1                                           57.98058
# 2                                           59.12239
# 3                                           52.47764
# 4                                           59.69450
#
#    Electric power sector net generation from utility-scale solar, United States, Monthly (billion kilowatthours)  \
# 0                                           5.012265
# 1                                           5.924216
# 2                                           7.522503
# 3                                           8.976820
# 4                                           9.742568
#
#    Total electric power sector net generation by all energy sources, United States, Monthly (billion kilowatthours)  \
# 0                                           326.5772
# 1                                           292.8734
# 2                                           306.3560
# 3                                           318.2363
# 4                                           388.0824
#
#    Electric power sector net generation from wind, United States, Monthly (billion kilowatthours)
# 0                                           32.66580
# 1                                           28.14019
# 2                                           28.36593
# 3                                           21.57470
# 4                                           24.94340

# %%
data['Date'] = pd.to_datetime(data['Date'])
df = data.set_index('Date')
df
# Out:
#             Electric power sector net generation from biomass, United States, Monthly (billion kilowatthours)  \
# Date
# 2020-12-01                                
United States, Monthly (billion kilowatthours)  \
# Date
# 2020-12-01                                           1.589645
# 2020-11-01                                           1.562592
# 2020-10-01                                           1.326140
# 2020-09-01                                           1.804214
# 2020-08-01                                           1.889336
# ...                                                       ...
# 2001-05-01                                           9.933711
# 2001-04-01                                          10.415996
# 2001-03-01                                          11.206700
# 2001-02-01                                           9.816608
# 2001-01-01                                          17.395981
#
#             Electric power sector net generation from renewable energy (all types), United States, Monthly (billion kilowatthours)  \
# Date
# 2020-12-01                                           64.88192
# 2020-11-01                                           57.98058
# 2020-10-01                                           59.12239
# 2020-09-01                                           52.47764
# 2020-08-01                                           59.69450
# ...                                                       ...
# 2001-05-01                                                NaN
# 2001-04-01                                                NaN
# 2001-03-01                                                NaN
# 2001-02-01                                                NaN
# 2001-01-01                                                NaN
#
#             Electric power sector net generation from utility-scale solar, United States, Monthly (billion kilowatthours)  \
# Date
# 2020-12-01                                           5.012265
# 2020-11-01                                           5.924216
# 2020-10-01                                           7.522503
# 2020-09-01                                           8.976820
# 2020-08-01                                           9.742568
# ...                                                       ...
# 2001-05-01                                                NaN
# 2001-04-01                                                NaN
# 2001-03-01                                                NaN
# 2001-02-01                                                NaN
# 2001-01-01                                                NaN
#
#             Total electric power sector net generation by all energy sources, United States, Monthly (billion kilowatthours)  \
# Date
# 2020-12-01                                           326.5772
# 2020-11-01                                           292.8734
# 2020-10-01                                           306.3560
# 2020-09-01                                           318.2363
# 2020-08-01                                           388.0824
# ...                                                       ...
# 2001-05-01                                                NaN
# 2001-04-01                                                NaN
# 2001-03-01                                                NaN
# 2001-02-01                                                NaN
# 2001-01-01                                                NaN
#
#             Electric power sector net generation from wind, United States, Monthly (billion kilowatthours)
# Date
# 2020-12-01                                          32.665800
# 2020-11-01                                          28.140190
# 2020-10-01                                          28.365930
# 2020-09-01                                          21.574700
# 2020-08-01                                          24.943400
# ...                                                       ...
# 2001-05-01                                           0.635029
# 2001-04-01                                           0.684694
# 2001-03-01                                           0.532120
# 2001-02-01                                           0.431243
# 2001-01-01                                           0.389251
#
# [240 rows x 15 columns]

# %%
price = pd.read_csv('EIA Data Sets/Data/prices.csv')
price['Date'] = pd.to_datetime(price['Date'])
price_df = price.set_index('Date')
price_df
# Out:
#             Retail Price of Electricity for All Sectors, U.S. Total, Monthly (cents per kilowatt hour)
# Date
# 1990-01-01                                            6.27000
# 1990-02-01                                            6.34000
# 1990-03-01                                            6.37000
# 1990-04-01                                            6.35000
# 1990-05-01                                            6.46000
# ...                                                       ...
# 2020-08-01                                           11.12406
# 2020-09-01                                           10.81302
# 2020-10-01                                           10.57964
# 2020-11-01                                           10.57496
# 2020-12-01                                           10.40510
#
# [372 rows x 1 columns]

# %%
price_gen = pd.merge(price_df,df, on='Date')
price_gen = price_gen.loc['2010-01-01':'2019-10-31']
price_gen.tail()
# Out:
#             Retail Price of Electricity for All Sectors, U.S. Total, Monthly (cents per kilowatt hour)  \
# Date
# 2019-06-01                                           10.80000
# 2019-07-01                                           11.06000
# 2019-08-01                                           10.98163
# 2019-09-01                                           10.69525
# 2019-10-01                                           10.46704
#
#             Electric power sector net generation from biomass, United States, Monthly (billion kilowatthours)  \
# Date
# 2019-06-01                                           2.500330
# 2019-07-01                                           2.659966
# 2019-08-01                                           2.102103
# 2019-09-01                                           2.100022
# 2019-10-01                                           2.396545
#
#             Electric power sector net generation from coal, United States, Monthly (billion kilowatthours)  \
# Date
# 2019-06-01                                          78.024793
# 2019-07-01                                         100.402957
# 2019-08-01                                         105.580100
# 2019-09-01                                          88.324590
# 2019-10-01                                          68.329570
#
#             Net energy for electricity load, United States, Monthly (billion kilowatthours)  \
# Date
# 2019-06-01                                         338.738883
# 2019-07-01                                         396.911009
# 2019-08-01                                         396.437600
# 2019-09-01                                         343.517200
# 2019-10-01                                         306.896700
#
#             Electric power sector net generation from geothermal, United States, Monthly (billion kilowatthours)  \
# Date
# 2019-06-01                                           1.370651
# 2019-07-01                                           1.426077
# 2019-08-01                                           1.373647
# 2019-09-01                                           1.304915
# 2019-10-01                                           1.389165
#
#             Electric power sector net generation from pumped storage hydropower, United States, Monthly (billion kilowatthours)  \
# Date
# 2019-06-01                                          -0.385296
# 2019-07-01                                          -0.622347
# 2019-08-01                                          -0.799442
# 2019-09-01                                          -0.646617
# 2019-10-01                                          -0.473988
#
#             Electric power sector net generation from conventional hydropower, United States, Monthly (billion kilowatthours)  \
# Date
# 2019-06-01                                          26.227339
# 2019-07-01                                          22.808609
# 2019-08-01                                          20.914850
# 2019-09-01                                          20.927660
# 2019-10-01                                          20.722700
#
#             Electric power sector net generation from natural gas, United States, Monthly (billion kilowatthours)  \
# Date
# 2019-06-01                                         128.333890
# 2019-07-01                                         164.789078
# 2019-08-01                                         164.225300
# 2019-09-01                                         135.224700
# 2019-10-01                                         120.144200
#
#             Electric power sector net generation from nuclear, United States, Monthly (billion kilowatthours)  \
# Date
# 2019-06-01                                          68.804879
# 2019-07-01                                          72.198595
# 2019-08-01                                          71.498100
# 2019-09-01                                          65.847270
# 2019-10-01                                          62.172640
#
#             Electric power sector net generation from other nonrenewable fuels, United States, Monthly (billion kilowatthours)  \
# Date
# 2019-06-01                                           0.599223
# 2019-07-01                                           0.618224
# 2019-08-01                                           0.490829
# 2019-09-01                                           0.325633
# 2019-10-01                                           0.608672
#
#             Electric power sector net generation from other gases, United States, Monthly (billion kilowatthours)  \
# Date
# 2019-06-01                                           0.344190
# 2019-07-01                                           0.404281
# 2019-08-01                                           0.420494
# 2019-09-01                                           0.355415
# 2019-10-01                                           0.158158
#
#             Electric power sector net generation from petroleum, United States, Monthly (billion kilowatthours)  \
# Date
# 2019-06-01                                           1.405163
# 2019-07-01                                           1.595532
# 2019-08-01                                           1.901299
# 2019-09-01                                           1.880829
# 2019-10-01                                           1.458057
#
#             Electric power sector net generation from renewable energy (all types), United States, Monthly (billion kilowatthours)  \
# Date
# 2019-06-01                                          61.612041
# 2019-07-01                                          57.524689
# 2019-08-01                                          53.120960
# 2019-09-01                                          52.205360
# 2019-10-01                                          54.499380
#
#             Electric power sector net generation from utility-scale solar, United States, Monthly (billion kilowatthours)  \
# Date
# 2019-06-01                                           8.139909
# 2019-07-01                                           8.182786
# 2019-08-01                                           7.578059
# 2019-09-01                                           7.066358
# 2019-10-01                                           5.989832
#
#             Total electric power sector net generation by all energy sources, United States, Monthly (billion kilowatthours)  \
# Date
# 2019-06-01                                         338.738883
# 2019-07-01                                         396.911009
# 2019-08-01                                         396.437600
# 2019-09-01                                         343.517200
# 2019-10-01                                         306.896700
#
#             Electric power sector net generation from wind, United States, Monthly (billion kilowatthours)
# Date
# 2019-06-01                                          23.373812
# 2019-07-01                                          22.447251
# 2019-08-01                                          21.152300
# 2019-09-01                                          20.806410
# 2019-10-01                                          24.001140

# %%
list(price_gen)
# Out:
# ['Retail Price of Electricity for All Sectors, U.S. Total, Monthly (cents per kilowatt hour)',
#  'Electric power sector net generation from biomass, United States, Monthly (billion kilowatthours)',
#  'Electric power sector net generation from coal, United States, Monthly (billion kilowatthours)',
#  'Net energy for electricity load, United States, Monthly (billion kilowatthours)',
#  'Electric power sector net generation from geothermal, United States, Monthly (billion kilowatthours)',
#  'Electric power sector net generation from pumped storage hydropower, United States, Monthly (billion kilowatthours)',
#  'Electric power sector net generation from conventional hydropower, United States, Monthly (billion kilowatthours)',
#  'Electric power sector net generation from natural gas, United States, Monthly (billion kilowatthours)',
#  'Electric power sector net generation from nuclear, United States, Monthly (billion kilowatthours)',
#  'Electric power sector net generation from other nonrenewable fuels, United States, Monthly (billion kilowatthours)',
#  'Electric power sector net generation from other gases, United States, Monthly (billion kilowatthours)',
#  'Electric power sector net generation from petroleum, United States, Monthly (billion kilowatthours)',
#  'Electric power sector net generation from renewable energy (all types), United States, Monthly (billion kilowatthours)',
#  'Electric power sector net generation from utility-scale solar, United States, Monthly (billion kilowatthours)',
#  'Total electric power sector net generation by all energy sources, United States, Monthly (billion kilowatthours)',
#  'Electric power sector net generation from wind, United States, Monthly (billion kilowatthours)']

# %%
price = price_gen['Retail Price of Electricity for All Sectors, U.S. Total, Monthly (cents per kilowatt hour)']
bio = price_gen['Electric power sector net generation from biomass, United States, Monthly (billion kilowatthours)']
geo = price_gen['Electric power sector net generation from geothermal, United States, Monthly (billion kilowatthours)']
hydro = price_gen['Electric power sector net generation from pumped storage hydropower, United States, Monthly (billion kilowatthours)']
conv_hydro = price_gen['Electric power sector net generation from conventional hydropower, United States, Monthly (billion kilowatthours)']
nat_gas = price_gen['Electric power sector net generation from natural gas, United States, Monthly (billion kilowatthours)']
nuc = price_gen['Electric power sector net generation from nuclear, United States, Monthly (billion kilowatthours)']
nonrenew = price_gen['Electric power sector net generation from other nonrenewable fuels, United States, Monthly (billion kilowatthours)']
coal = price_gen['Electric power sector net generation from coal, United States, Monthly (billion kilowatthours)']
petro = price_gen['Electric power sector net generation from petroleum, United States, Monthly (billion kilowatthours)']
renew_sum = price_gen['Electric power sector net generation from renewable energy (all types), United States, Monthly (billion kilowatthours)']
total = price_gen['Total electric power sector net generation by all energy sources, United States, Monthly (billion kilowatthours)']
solar = price_gen['Electric power sector net generation from utility-scale solar, United States, Monthly (billion kilowatthours)']
wind = price_gen['Electric power sector net generation from wind, United States, Monthly (billion kilowatthours)']

# %%
plt.plot(wind)
plt.plot(solar)
plt.plot(bio)
plt.plot(geo)
plt.plot(hydro)
plt.plot(renew_sum)

# %%
plt.scatter(price, renew_sum)
plt.title("Price vs Renewables Generation")
# Out:
# Text(0.5, 1.0, 'Price vs Renewables Generation')

# %%
plt.scatter(price, nat_gas)
plt.title("Price vs Natual Gas")
# Out:
# Text(0.5, 1.0, 'Price vs Natual Gas')

# %%
X = price
y = nat_gas
X1 = sm.add_constant(X)

# %%
#make regression model
model = sm.OLS(y,X1)

# %%
# fit model and print results
results = model.fit()
print(results.summary())
# Out:
#                                                                       OLS Regression Results
# =================================================================================================================================================================
# Dep. Variable:     Electric power sector net generation from natural gas, United States, Monthly (billion kilowatthours)   R-squared:                       0.678
# Model:                                                                                                               OLS   Adj. R-squared:                  0.675
# Method:                                                                                                    Least Squares   F-statistic:                     244.1
# Date:                                                                                                   Tue, 12 Nov 2019   Prob (F-statistic):           2.61e-30
# Time:                                                                                                           21:13:36   Log-Likelihood:                -472.55
# No. Observations:                                                                                                    118   AIC:                             949.1
# Df Residuals:                                                                                                        116   BIC:                             954.6
# Df Model:                                                                                                              1
# Covariance Type:                                                                                               nonrobust
# ==============================================================================================================================================================
#                                                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                       -347.6448     28.425    -12.230      0.000    -403.944    -291.346
# Retail Price of Electricity for All Sectors, U.S. Total, Monthly (cents per kilowatt hour)    43.4532      2.781     15.624      0.000      37.945      48.962
# ==============================================================================
# Omnibus:                        1.643   Durbin-Watson:                   0.582
# Prob(Omnibus):                  0.440   Jarque-Bera (JB):                1.374
# Skew:                           0.263   Prob(JB):                        0.503
# Kurtosis:                       3.046   Cond. No.                         238.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# alternatively scipy linear regression
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(X, y)

print(r_value)
# Out:
# 0.8233274818742657

# %%
plt.plot(nat_gas, price, 'r.')

ax = plt.axis()
x = np.linspace(ax[0], ax[1] + 0.01)

plt.plot(x, model.params[0] + model.params[1] * x, 'b', lw=2)

plt.grid(True)
plt.axis('tight')
plt.xlabel('First Trust NASDAQ Clean Edge Green Energy Index Fund ')
plt.ylabel('S&p 500 Returns')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-447a68f47e43> in <module>
#       4 x = np.linspace(ax[0], ax[1] + 0.01)
#       5
# ----> 6 plt.plot(x, model.params[0] + model.params[1] * x, 'b', lw=2)
#       7
#       8 plt.grid(True)
#
# AttributeError: 'OLS' object has no attribute 'params'
